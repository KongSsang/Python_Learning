# %% [markdown]
# array() 함수로 2차원 배열 만들기

# %%
import numpy as np
my_arr = np.array([[10, 20, 30],[40, 50, 60]])
my_arr
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %% [markdown]
# **type() 함수로 넘파이 배열인지 확인하기**

# %%
import numpy as np
my_arr = np.array([[10, 20, 30],[40, 50, 60]])
type(my_arr)
# Out:
# numpy.ndarray

# %% [markdown]
# **넘파이 배열에서 요소 선택**

# %%
import numpy as np
my_arr[0][2]
# Out:
# 30

# %% [markdown]
# **넘파이 내장함수 사용해보기**

# %%
import numpy as np
my_arr = np.array([[10, 20, 30],[40, 50, 60]])
np.sum(my_arr)
# Out:
# 210
